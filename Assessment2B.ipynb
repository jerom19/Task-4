# %% [markdown]
# <a href="https://colab.research.google.com/github/jerom19/Task-4/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
files = os.path.join("/content/", "college*.csv")
files = glob.glob(files)
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
merge=df.to_csv('merge.csv')
df
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
C_S=df.loc[df['CodeKata Score']>15000]
exeeds=C_S.to_csv('expectation_exeeds.csv')
C_S
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 0   ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 35      A.Dharani    82.0        NaN   20.0                     NaN
# 36    V.JEEVITHA     82.0        NaN   20.0                     NaN
# 37    HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#     Previous Geekions  CodeKata Score                              Department  \
# 0               19400           19400  Electronics and Electrical Engineering
# 35              24500           24500        Computer Science and Engineering
# 36              21740           21740        Computer Science and Engineering
# 37              19680           19680        Computer Science and Engineering
#
#     Rising
# 0        0
# 35       0
# 36       0
# 37       0

# %%
R_E=df.loc[(df['CodeKata Score']<15000) & (df['CodeKata Score']>1000)]
reched=R_E.to_csv('Reached_expectations.csv')
R_E
# Out:
#                           Name  python  python_en  mysql  \
# 1                      Chandru     0.0       20.0    0.0
# 2            Ganesh Ramkumar R    -1.0       55.0   24.0
# 3              Bodipudi Harini    -1.0        0.0   35.0
# 4                    VIINU V P    -1.0      100.0   24.0
# 5                   Poojitha Y     0.0       78.0   35.0
# ..                         ...     ...        ...    ...
# 80                  PRAVEENA K   100.0        NaN  100.0
# 81  siva sai perumal polisetti   100.0        NaN   12.0
# 82                 MadhumathiB    16.0        NaN   35.0
# 83                   b.akshaya    82.0        NaN    0.0
# 84                    bavithra     0.0        NaN  100.0
#
#     computational_thinking  Previous Geekions  CodeKata Score  \
# 1                      0.0              14150           14490
# 2                      6.0               8790           10790
# 3                     -1.0              10040           10040
# ...

# %%
N_I=df.loc[(df['CodeKata Score']<10000) & (df['CodeKata Score']>7000)]
reched=N_I.to_csv('Needs_Improvement.csv')
N_I
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P    -1.0      100.0   24.0                    -1.0
# 5               Poojitha Y     0.0       78.0   35.0                     0.0
# 6   Gowtham Chandrasekaran    -1.0        0.0    0.0                     3.0
# 7                Gowtham R    -1.0       60.0    4.0                     6.0
# 8                 shifak N    58.0        0.0    0.0                     0.0
# 9                  Balaji     -1.0      100.0   20.0                     0.0
# 10                Rushitha    -1.0       15.0   62.0                     9.0
# 11    Balaraman Muthupandi    -1.0        9.0    0.0                     0.0
# 12                JPradhap   100.0        0.0    0.0                     0.0
# 13           SRIRAMKUMAR B    -1.0        0.0    0.0                     0.0
# 14               Praneetha    -1.0       23.0  100.0                    -1.0
# ...

# %%
U_S=df.loc[df['CodeKata Score']<7000]
reched=U_S.to_csv('Unsatisfactory.csv')
U_S
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 18   Narasimhan Y L    -1.0       -1.0    0.0                     0.0
# 19     Leelakrishna    -1.0        6.0    4.0                     0.0
# 20   PremsagarReddy    -1.0       20.0    0.0                     0.0
# 21        pradeeban    16.0       20.0   24.0                     0.0
# 22      santhoshini    -1.0       43.0    0.0                     0.0
# ..              ...     ...        ...    ...                     ...
# 114    KarthikeyanS    45.0        NaN    0.0                     NaN
# 115        BARATH.P    29.0        NaN    0.0                     NaN
# 116   N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117    mohamed nabi     0.0        NaN    0.0                     NaN
# 118  yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 18                4800            6800
# 19                5300            6640
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['Average']=df[['Previous Geekions','CodeKata Score']].mean(axis=1)
df['Average']
# Out:
# 0      19400.0
# 1      14320.0
# 2       9790.0
# 3      10040.0
# 4       9150.0
#         ...
# 114        0.0
# 115        0.0
# 116        0.0
# 117        0.0
# 118        0.0
# Name: Average, Length: 119, dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
df['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['avg'] = df.iloc[:,1:5].mean(axis=1)
df['avg']
# Out:
# 0      35.00
# 1       5.00
# 2      21.00
# 3       8.25
# 4      30.50
#        ...
# 114    22.50
# 115    14.50
# 116    41.00
# 117     0.00
# 118    13.50
# Name: avg, Length: 119, dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
R_S=df.nlargest(3, ['Rising'])
R_S
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N    58.0        0.0    0.0                     0.0
# 2   Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 18     Narasimhan Y L    -1.0       -1.0    0.0                     0.0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 2                8790           10790        Computer Science and Engineering
# 18               4800            6800        Computer Science and Engineering
#
#     Rising  Average   avg
# 8     3140   6750.0  14.5
# 2     2000   9790.0  21.0
# 18    2000   5800.0  -0.5

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
S_S=df.nlargest(3, ['Previous Geekions'])
S_S
# Out:
#            Name  python  python_en  mysql  computational_thinking  \
# 35    A.Dharani    82.0        NaN   20.0                     NaN
# 36  V.JEEVITHA     82.0        NaN   20.0                     NaN
# 37  HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#     Previous Geekions  CodeKata Score                        Department  \
# 35              24500           24500  Computer Science and Engineering
# 36              21740           21740  Computer Science and Engineering
# 37              19680           19680  Computer Science and Engineering
#
#     Rising  Average    avg
# 35       0  24500.0   51.0
# 36       0  21740.0   51.0
# 37       0  19680.0  100.0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
#df['Department']=df["Department"].map({'Computer Science and Engineering':1,
              #'Electronics and Electrical Engineering':0,
              #'Electronics and Communication Engineering':2})
#df
perf=df[['Department','CodeKata Score']]
perf.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
perf2=df[['Department','Previous Geekions']]
perf2.groupby(['Department']).sum().plot(kind='bar', y='Previous Geekions')
